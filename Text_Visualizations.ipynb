# %% [markdown]
# <a href="https://colab.research.google.com/github/saketh0641/Saketh-s-Repo./blob/main/Text_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text, output_image_path):
    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Save the generated WordCloud image
    wordcloud.to_file(output_image_path)

    # Display the image using matplotlib (optional)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Test the function with the provided text
text = 'data science machine learning artificial intelligence'
output_image_path = 'wordcloud.png'
generate_wordcloud(text, output_image_path)
